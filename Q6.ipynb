# %% [markdown]
# ### QUESTION 6:
#
# We define three time periods and their corresponding window length as follows:
# 1. Before Feb. 1, 8:00 a.m.: 1-hour window
# 2. Between Feb. 1, 8:00 a.m. and 8:00 p.m.: 5-minute window
# 3. After Feb. 1, 8:00 p.m.: 1-hour window
#
# For each hashtag, train 3 regression models, one for each of these time periods (the times are all in PST). Report the MSE and R-squared score for each case.

# %%
hash_tags = ['#gohawks','#gopatriots','#nfl','#patriots','#sb49','#superbowl']

# %%
import pickle

def save_object(data, fileName):
    with open('pynb_data/'+fileName + ".pickle", 'wb') as f:
        pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
        
def load_object(fileName):
    try:
        with open('pynb_data/'+fileName + ".pickle", 'rb') as f:
            data = pickle.load(f)
            return data
    except IOError:
        print("Could not read file: " + fileName)

# %%
import json

def getMinAndMaxTs(tag):
    filename = 'data/tweets_'+tag+'.txt'
    max_ts = 0
    min_ts = 1552522378
    with open(filename) as f:
        for line in f:
            json_object = json.loads(line)
            timestamp = json_object['citation_date']
            if(timestamp < min_ts):                
                min_ts = timestamp
            
            if(timestamp > max_ts):
                max_ts = timestamp
                
    return [min_ts,max_ts]

tagsToMinTs = {}
tagsToMaxTs = {}
for tag in hash_tags:
    ts_list = getMinAndMaxTs(tag)
    tagsToMinTs[tag] = (ts_list[0])
    tagsToMaxTs[tag] = (ts_list[1])

# %%
import math
import datetime
import pytz


def getLocalHour(timestamp):
    d = datetime.datetime.fromtimestamp(timestamp)
    pst = pytz.timezone('America/Los_Angeles')
    d = pst.localize(d)
    return d.hour

def getWindowNumber(start_ts, curr_ts, window):
    elapsed = (curr_ts - start_ts)/(window*1.0)
    windowNum = math.ceil(elapsed)
    return windowNum    

def getFeatures(tag,start_ts,end_ts,window):
    windowToTweets = {}
    windowToRetweets = {}
    windowToFollowerCount = {}
    windowToMaxFollowers = {}
    features = []
    labels = []
    
    filename = 'data/tweets_'+tag+'.txt'
    with open(filename) as f:
        for line in f:
            json_object = json.loads(line)
            timestamp = json_object['citation_date']
            
            if timestamp < start_ts or timestamp > end_ts:                            
                continue
                
            key = getWindowNumber(start_ts,timestamp,window)

            if key not in windowToTweets.keys():
                windowToTweets[key]=0
            windowToTweets[key]+=1
            
            retweetCount = json_object['metrics']['citations']['total']        
            
            if key not in windowToRetweets.keys():
                windowToRetweets[key]=0
            windowToRetweets[key]+=retweetCount
        
            followerCount = json_object['author']['followers']
            if key not in windowToFollowerCount.keys():
                windowToFollowerCount[key]=0
            windowToFollowerCount[key]+=followerCount
        
            if key not in windowToMaxFollowers.keys():
                windowToMaxFollowers[key]=0
            windowToMaxFollowers[key] = max(windowToMaxFollowers[key],followerCount)            
            
        for period in range(start_ts,end_ts,window):
            key = getWindowNumber(start_ts,period,window)
            tweetCount = windowToTweets.get(key, 0)
            retweetCount = windowToRetweets.get(key,0)
            followerCount = windowToFollowerCount.get(key,0)
            maxFollowers = windowToMaxFollowers.get(key,0)

            h = getLocalHour(period)
            
            feature = [tweetCount, retweetCount, followerCount, maxFollowers, h]
            features.append(feature)
                
            nextKey = getWindowNumber(start_ts, period + window, window)
            labels.append(windowToTweets.get(nextKey,0))
                
    return features,labels

# %%
import statsmodels.api as sm
import statsmodels.tools.eval_measures as ste

print("Linear Regression models for time period 1")

for tag in hash_tags:
    tp1_window_size = 3600 # 1 hour window size
    
    #find the start_ts based on minimum time for this tag
    tp1_start_ts = tp1_window_size * math.floor(tagsToMinTs[tag]/(tp1_window_size*1.0))
    tp1_end_ts = 1422806400
    features,labels = getFeatures(tag,tp1_start_ts,tp1_end_ts,tp1_window_size)
    
    print('\nLinear Regression Model for {}'.format(tag))
   
    X_orig = features
    y = labels
    
    #     https://becominghuman.ai/stats-models-vs-sklearn-for-linear-regression-f19df95ad99b
    X = sm.add_constant(X_orig)
    
    model = sm.OLS(y,X)
    results = model.fit()
    pred_y = results.predict(X)

    print("\nMSE : {}".format(ste.mse(pred_y, y,axis=0)))
    print("R-squared : {}".format(results.rsquared))    
    print("P values for the features are \n {} \n\n".format(results.pvalues))

    print(results.summary())
    print('---'*20)
    print('\n\n')
    
    save_object(features, "q6_tp1_features_{}".format(tag))
    save_object(labels, "q6_tp1_labels_{}".format(tag))
# Out:
# Linear Regression models for time period 1
#
# Linear Regression Model for #gohawks
#
# MSE : 715120.8608315315
# R-squared : 0.3047777689514175
# P values for the features are
#  [3.36075078e-01 2.75387335e-12 3.36800976e-04 3.36224274e-03
#  6.59176417e-02 3.24118770e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     38.05
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           2.28e-32
# Time:                        12:06:16   Log-Likelihood:                -3590.0
# No. Observations:                 440   AIC:                             7192.
# Df Residuals:                     434   BIC:                             7216.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         75.0350     77.917      0.963      0.336     -78.106     228.176
# x1             2.0364      0.283      7.195      0.000       1.480       2.593
# x2            -0.4056      0.112     -3.614      0.000      -0.626      -0.185
# x3            -0.0005      0.000     -2.949      0.003      -0.001      -0.000
# x4             0.0004      0.000      1.844      0.066    -2.5e-05       0.001
# x5             5.9069      5.984      0.987      0.324      -5.854      17.668
# ==============================================================================
# Omnibus:                      869.557   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1055311.054
# Skew:                          13.298   Prob(JB):                         0.00
# Kurtosis:                     241.443   Cond. No.                     4.17e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #gopatriots
#
# MSE : 1750.6410617101724
# R-squared : 0.572341259658127
# P values for the features are
#  [8.23996448e-01 2.16809304e-20 4.22770677e-01 3.12488058e-09
#  2.06428728e-09 9.28432587e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.572
# Model:                            OLS   Adj. R-squared:                  0.567
# Method:                 Least Squares   F-statistic:                     115.9
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.43e-77
# Time:                        12:06:18   Log-Likelihood:                -2262.1
# No. Observations:                 439   AIC:                             4536.
# Df Residuals:                     433   BIC:                             4561.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8638      3.882      0.223      0.824      -6.765       8.493
# x1             1.7929      0.184      9.737      0.000       1.431       2.155
# x2            -0.0926      0.115     -0.802      0.423      -0.320       0.134
# x3            -0.0010      0.000     -6.051      0.000      -0.001      -0.001
# x4             0.0010      0.000      6.123      0.000       0.001       0.001
# x5             0.0264      0.294      0.090      0.928      -0.551       0.604
# ==============================================================================
# Omnibus:                      748.425   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           411055.458
# Skew:                           9.926   Prob(JB):                         0.00
# Kurtosis:                     151.587   Cond. No.                     4.75e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #nfl
#
# MSE : 65814.87123258511
# R-squared : 0.5117341292146926
# P values for the features are
#  [2.75482217e-04 3.53566139e-06 9.57353732e-01 2.51255821e-04
#  9.13226756e-03 8.33815049e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     90.97
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           2.45e-65
# Time:                        12:06:37   Log-Likelihood:                -3065.1
# No. Observations:                 440   AIC:                             6142.
# Df Residuals:                     434   BIC:                             6167.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         89.8958     24.512      3.667      0.000      41.718     138.074
# x1             0.4731      0.101      4.698      0.000       0.275       0.671
# x2             0.0025      0.046      0.054      0.957      -0.089       0.093
# x3          6.787e-05   1.84e-05      3.692      0.000    3.17e-05       0.000
# x4          -6.06e-05   2.31e-05     -2.619      0.009      -0.000   -1.51e-05
# x5            -0.3798      1.809     -0.210      0.834      -3.935       3.176
# ==============================================================================
# Omnibus:                      735.271   Durbin-Watson:                   2.266
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           465353.595
# Skew:                           9.429   Prob(JB):                         0.00
# Kurtosis:                     161.200   Cond. No.                     5.73e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.73e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #patriots
#
# MSE : 337466.2735465752
# R-squared : 0.5671982513823107
# P values for the features are
#  [2.16108734e-01 1.05389354e-01 6.62226673e-02 5.08695901e-13
#  5.12701066e-10 8.71330328e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     113.8
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.24e-76
# Time:                        12:07:11   Log-Likelihood:                -3424.8
# No. Observations:                 440   AIC:                             6862.
# Df Residuals:                     434   BIC:                             6886.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         66.7988     53.924      1.239      0.216     -39.187     172.784
# x1            -0.2997      0.185     -1.623      0.105      -0.663       0.063
# x2             0.1398      0.076      1.842      0.066      -0.009       0.289
# x3             0.0002   3.02e-05      7.450      0.000       0.000       0.000
# x4            -0.0003   4.82e-05     -6.360      0.000      -0.000      -0.000
# x5             0.6629      4.090      0.162      0.871      -7.376       8.702
# ==============================================================================
# Omnibus:                      564.592   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190261.007
# Skew:                           5.681   Prob(JB):                         0.00
# Kurtosis:                     104.236   Cond. No.                     8.06e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
# Linear Regression Model for #sb49
#
# MSE : 6885.556248416906
# R-squared : 0.8677596629510165
# P values for the features are
#  [1.71555069e-02 7.58140847e-92 5.46570391e-06 2.08563720e-03
#  3.30013260e-01 4.20294474e-03]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     564.3
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):          2.40e-186
# Time:                        12:08:04   Log-Likelihood:                -2545.2
# No. Observations:                 436   AIC:                             5102.
# Df Residuals:                     430   BIC:                             5127.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.8025      7.858      2.393      0.017       3.357      34.248
# x1             1.0607      0.040     26.364      0.000       0.982       1.140
# x2             0.0224      0.005      4.604      0.000       0.013       0.032
# x3         -4.247e-06   1.37e-06     -3.097      0.002   -6.94e-06   -1.55e-06
# x4          3.316e-06    3.4e-06      0.975      0.330   -3.37e-06       1e-05
# x5            -1.6769      0.583     -2.878      0.004      -2.822      -0.532
# ==============================================================================
# Omnibus:                      233.433   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7917.158
# Skew:                           1.652   Prob(JB):                         0.00
# Kurtosis:                      23.613   Cond. No.                     1.87e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #superbowl
#
# MSE : 515305.47898970684
# R-squared : 0.40199273406595415
# P values for the features are
#  [6.37677297e-02 2.33234054e-03 4.63667767e-01 8.76661427e-06
#  1.18754159e-01 9.78131426e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     58.35
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           2.19e-46
# Time:                        12:10:00   Log-Likelihood:                -3517.9
# No. Observations:                 440   AIC:                             7048.
# Df Residuals:                     434   BIC:                             7072.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        127.2324     68.458      1.859      0.064      -7.318     261.783
# x1             0.3769      0.123      3.062      0.002       0.135       0.619
# x2             0.0439      0.060      0.733      0.464      -0.074       0.162
# x3          2.652e-05   5.89e-06      4.499      0.000    1.49e-05    3.81e-05
# x4         -3.874e-05   2.48e-05     -1.563      0.119   -8.74e-05    9.97e-06
# x5            -0.1376      5.016     -0.027      0.978      -9.996       9.721
# ==============================================================================
# Omnibus:                      626.701   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           112680.002
# Skew:                           7.335   Prob(JB):                         0.00
# Kurtosis:                      80.013   Cond. No.                     2.83e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.83e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------

# %%
import statsmodels.api as sm
import statsmodels.tools.eval_measures as ste

print("Linear Regression models for time period 2")

#tp2
for tag in hash_tags:
    tp2_window_size = 300 # 5 minute window size
    tp2_start_ts = 1422806400
    tp2_end_ts = 1422849600
    features,labels = getFeatures(tag,tp2_start_ts,tp2_end_ts,tp2_window_size)
    
    print('\nLinear Regression Model for {}'.format(tag))
    X_orig = features
    y = labels
    
    #     https://becominghuman.ai/stats-models-vs-sklearn-for-linear-regression-f19df95ad99b
    X = sm.add_constant(X_orig)
    
    model = sm.OLS(y,X)
    results = model.fit()
    pred_y = results.predict(X)

    print("\nMSE : {}".format(ste.mse(pred_y, y,axis=0)))
    print("R-squared : {}".format(results.rsquared))    
    print("P values for the features are \n {} \n\n".format(results.pvalues))

    print(results.summary())
    print('---'*20)
    print('\n\n')
    
    save_object(features, "q6_tp2_features_{}".format(tag))
    save_object(labels, "q6_tp2_labels_{}".format(tag))
    print("Finished {}".format(tag))
# Out:
# Linear Regression models for time period 2
#
# Linear Regression Model for #gohawks
#
# MSE : 72065.96223196147
# R-squared : 0.4928205826269495
# P values for the features are
#  [0.2745786  0.00168241 0.82192757 0.13860422 0.17855737 0.02367774]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     26.82
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           7.10e-19
# Time:                        12:22:18   Log-Likelihood:                -1009.7
# No. Observations:                 144   AIC:                             2031.
# Df Residuals:                     138   BIC:                             2049.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -107.6842     98.168     -1.097      0.275    -301.792      86.424
# x1             0.6862      0.214      3.204      0.002       0.263       1.110
# x2             0.0378      0.167      0.225      0.822      -0.293       0.369
# x3            -0.0001    8.1e-05     -1.490      0.139      -0.000    3.95e-05
# x4             0.0002      0.000      1.352      0.179   -8.84e-05       0.000
# x5            18.9868      8.300      2.288      0.024       2.576      35.398
# ==============================================================================
# Omnibus:                       97.512   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              839.890
# Skew:                           2.298   Prob(JB):                    4.17e-183
# Kurtosis:                      13.902   Cond. No.                     6.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #gohawks
#
# Linear Regression Model for #gopatriots
#
# MSE : 13314.55236152159
# R-squared : 0.48097519293242996
# P values for the features are
#  [5.18520905e-03 4.05144082e-01 9.21182102e-03 6.21015583e-01
#  9.95025280e-01 1.94315732e-04]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.481
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     25.58
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           3.37e-18
# Time:                        12:22:19   Log-Likelihood:                -888.08
# No. Observations:                 144   AIC:                             1788.
# Df Residuals:                     138   BIC:                             1806.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -125.0997     44.040     -2.841      0.005    -212.180     -38.019
# x1            -0.2900      0.347     -0.835      0.405      -0.977       0.397
# x2             0.7030      0.266      2.641      0.009       0.177       1.229
# x3         -9.068e-05      0.000     -0.496      0.621      -0.000       0.000
# x4          1.302e-06      0.000      0.006      0.995      -0.000       0.000
# x5            13.6713      3.570      3.829      0.000       6.612      20.731
# ==============================================================================
# Omnibus:                      144.167   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2102.089
# Skew:                           3.747   Prob(JB):                         0.00
# Kurtosis:                      20.152   Cond. No.                     1.36e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #gopatriots
#
# Linear Regression Model for #nfl
#
# MSE : 20807.63611887527
# R-squared : 0.8190305351523018
# P values for the features are
#  [1.19667189e-01 9.33619577e-16 1.71526277e-02 2.98702198e-01
#  8.69585981e-01 2.71636752e-02]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     124.9
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.96e-49
# Time:                        12:22:36   Log-Likelihood:                -920.23
# No. Observations:                 144   AIC:                             1852.
# Df Residuals:                     138   BIC:                             1870.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -98.0817     62.637     -1.566      0.120    -221.934      25.770
# x1             1.1165      0.123      9.093      0.000       0.874       1.359
# x2            -0.1166      0.048     -2.413      0.017      -0.212      -0.021
# x3         -2.808e-05   2.69e-05     -1.043      0.299   -8.13e-05    2.51e-05
# x4         -6.135e-06   3.73e-05     -0.164      0.870   -7.99e-05    6.76e-05
# x5            12.3466      5.529      2.233      0.027       1.413      23.280
# ==============================================================================
# Omnibus:                       69.028   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              370.264
# Skew:                           1.628   Prob(JB):                     3.97e-81
# Kurtosis:                      10.149   Cond. No.                     1.27e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.27e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #nfl
#
# Linear Regression Model for #patriots
#
# MSE : 664677.1632637924
# R-squared : 0.714537103484636
# P values for the features are
#  [1.98366328e-01 2.04364666e-04 9.19065355e-01 6.33730722e-03
#  1.30450668e-01 9.90149259e-03]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     69.09
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           7.31e-36
# Time:                        12:23:05   Log-Likelihood:                -1169.6
# No. Observations:                 144   AIC:                             2351.
# Df Residuals:                     138   BIC:                             2369.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -412.9562    319.518     -1.292      0.198   -1044.740     218.828
# x1             0.9321      0.244      3.815      0.000       0.449       1.415
# x2             0.0225      0.221      0.102      0.919      -0.414       0.459
# x3            -0.0001   5.07e-05     -2.772      0.006      -0.000   -4.03e-05
# x4             0.0002      0.000      1.521      0.130   -4.99e-05       0.000
# x5            64.6467     24.717      2.615      0.010      15.774     113.520
# ==============================================================================
# Omnibus:                      116.880   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1004.544
# Skew:                           2.984   Prob(JB):                    7.35e-219
# Kurtosis:                      14.481   Cond. No.                     2.41e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #patriots
# Linear Regression Model for #sb49
#
# MSE : 1311055.597774237
# R-squared : 0.8644049008009105
# P values for the features are
#  [5.83113296e-01 1.71233396e-36 5.52950901e-01 7.60020290e-01
#  3.73008733e-01 8.77794517e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     175.9
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           4.76e-58
# Time:                        12:23:56   Log-Likelihood:                -1218.5
# No. Observations:                 144   AIC:                             2449.
# Df Residuals:                     138   BIC:                             2467.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        240.9646    438.007      0.550      0.583    -625.108    1107.037
# x1             0.9745      0.056     17.349      0.000       0.863       1.086
# x2            -0.0233      0.039     -0.595      0.553      -0.101       0.054
# x3         -2.187e-06   7.14e-06     -0.306      0.760   -1.63e-05    1.19e-05
# x4          1.549e-05   1.73e-05      0.894      0.373   -1.88e-05    4.98e-05
# x5             5.2816     34.285      0.154      0.878     -62.510      73.073
# ==============================================================================
# Omnibus:                       41.310   Durbin-Watson:                   2.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              621.982
# Skew:                          -0.364   Prob(JB):                    8.67e-136
# Kurtosis:                      13.155   Cond. No.                     2.20e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #sb49
#
# Linear Regression Model for #superbowl
#
# MSE : 6827285.886663284
# R-squared : 0.8902938824559525
# P values for the features are
#  [5.04177666e-01 1.90294943e-21 2.63701257e-02 5.01659084e-01
#  2.52868244e-01 4.02734133e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     224.0
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           2.23e-64
# Time:                        12:25:21   Log-Likelihood:                -1337.4
# No. Observations:                 144   AIC:                             2687.
# Df Residuals:                     138   BIC:                             2705.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -724.1093   1081.269     -0.670      0.504   -2862.106    1413.887
# x1             1.0441      0.092     11.330      0.000       0.862       1.226
# x2            -0.0355      0.016     -2.245      0.026      -0.067      -0.004
# x3         -1.044e-05   1.55e-05     -0.674      0.502   -4.11e-05    2.02e-05
# x4          7.309e-05   6.37e-05      1.148      0.253   -5.28e-05       0.000
# x5            77.5645     92.412      0.839      0.403    -105.162     260.291
# ==============================================================================
# Omnibus:                       43.743   Durbin-Watson:                   1.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              261.480
# Skew:                           0.869   Prob(JB):                     1.66e-57
# Kurtosis:                       9.369   Cond. No.                     3.34e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #superbowl

# %%
print("Linear Regression models for time period 3")

#tp3
for tag in hash_tags:
    print("Started building feature vector for {}".format(tag))
    tp3_window_size = 3600 # 1 hour window size
    tp3_start_ts = 1422849600
    tp3_end_ts = tp3_window_size * math.ceil(tagsToMaxTs[tag]/(tp3_window_size*1.0))
    features,labels = getFeatures(tag,tp3_start_ts,tp3_end_ts,tp3_window_size)
    
    print('\nLinear Regression Model for {}'.format(tag))
    X_orig = features
    y = labels
    
    #     https://becominghuman.ai/stats-models-vs-sklearn-for-linear-regression-f19df95ad99b
    X = sm.add_constant(X_orig)
    
    model = sm.OLS(y,X)
    results = model.fit()
    pred_y = results.predict(X)

    print("\nMSE : {}".format(ste.mse(pred_y, y,axis=0)))
    print("R-squared : {}".format(results.rsquared))    
    print("P values for the features are \n {} \n\n".format(results.pvalues))

    print(results.summary())
    print('---'*20)
    print('\n\n')
    
    save_object(features, "q6_tp3_features_{}".format(tag))
    save_object(labels, "q6_tp3_labels_{}".format(tag))
    print("Finished {}".format(tag))
# Out:
# Linear Regression models for time period 3
# Started building feature vector for #gohawks
#
# Linear Regression Model for #gohawks
#
# MSE : 8974.299492954375
# R-squared : 0.49458221714108497
# P values for the features are
#  [0.97537044 0.68370654 0.12340042 0.01034152 0.01459041 0.26720334]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     23.68
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.53e-16
# Time:                        12:25:34   Log-Likelihood:                -758.19
# No. Observations:                 127   AIC:                             1528.
# Df Residuals:                     121   BIC:                             1545.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5404     17.468     -0.031      0.975     -35.122      34.041
# x1             0.0998      0.244      0.408      0.684      -0.384       0.584
# x2            -0.0329      0.021     -1.551      0.123      -0.075       0.009
# x3             0.0010      0.000      2.605      0.010       0.000       0.002
# x4            -0.0010      0.000     -2.478      0.015      -0.002      -0.000
# x5             1.4023      1.258      1.115      0.267      -1.088       3.893
# ==============================================================================
# Omnibus:                      227.069   Durbin-Watson:                   1.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30207.235
# Skew:                           7.831   Prob(JB):                         0.00
# Kurtosis:                      76.913   Cond. No.                     6.23e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.23e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #gohawks
# Started building feature vector for #gopatriots
#
# Linear Regression Model for #gopatriots
#
# MSE : 357.49423273712614
# R-squared : 0.24925167713935326
# P values for the features are
#  [0.81171066 0.26909207 0.72133605 0.7057794  0.57189594 0.45715265]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     7.835
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           2.13e-06
# Time:                        12:25:36   Log-Likelihood:                -540.45
# No. Observations:                 124   AIC:                             1093.
# Df Residuals:                     118   BIC:                             1110.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8534      3.575      0.239      0.812      -6.225       7.932
# x1             0.5806      0.523      1.110      0.269      -0.455       1.616
# x2             0.0191      0.053      0.358      0.721      -0.087       0.125
# x3            -0.0004      0.001     -0.378      0.706      -0.002       0.002
# x4             0.0007      0.001      0.567      0.572      -0.002       0.003
# x5             0.1892      0.254      0.746      0.457      -0.313       0.691
# ==============================================================================
# Omnibus:                      238.348   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41002.416
# Skew:                           8.805   Prob(JB):                         0.00
# Kurtosis:                      90.326   Cond. No.                     3.75e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.75e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #gopatriots
# Started building feature vector for #nfl
#
# Linear Regression Model for #nfl
#
# MSE : 18827.16005654312
# R-squared : 0.7788238972562465
# P values for the features are
#  [5.63603422e-03 8.17400506e-11 6.05606861e-01 3.32192084e-01
#  3.88798727e-01 3.55058122e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     90.85
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.51e-40
# Time:                        12:25:52   Log-Likelihood:                -855.96
# No. Observations:                 135   AIC:                             1724.
# Df Residuals:                     129   BIC:                             1741.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         78.3688     27.835      2.815      0.006      23.296     133.442
# x1             0.8442      0.119      7.083      0.000       0.608       1.080
# x2            -0.0247      0.048     -0.518      0.606      -0.119       0.070
# x3          2.667e-05   2.74e-05      0.973      0.332   -2.75e-05    8.09e-05
# x4         -3.327e-05   3.85e-05     -0.865      0.389      -0.000    4.29e-05
# x5            -1.8196      1.960     -0.928      0.355      -5.698       2.059
# ==============================================================================
# Omnibus:                       49.475   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.252
# Skew:                           1.371   Prob(JB):                     8.69e-34
# Kurtosis:                       7.421   Cond. No.                     6.76e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.76e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #nfl
# Started building feature vector for #patriots
#
# Linear Regression Model for #patriots
#
# MSE : 99709.44364066204
# R-squared : 0.4197839622754397
# P values for the features are
#  [0.96682663 0.03774135 0.00861161 0.05573092 0.10487382 0.22844587]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     18.67
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           6.35e-14
# Time:                        12:26:23   Log-Likelihood:                -968.48
# No. Observations:                 135   AIC:                             1949.
# Df Residuals:                     129   BIC:                             1966.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3258     55.815      0.042      0.967    -108.106     112.757
# x1             0.5773      0.275      2.099      0.038       0.033       1.121
# x2            -0.0442      0.017     -2.668      0.009      -0.077      -0.011
# x3          7.411e-05   3.84e-05      1.931      0.056   -1.84e-06       0.000
# x4         -7.689e-05   4.71e-05     -1.633      0.105      -0.000    1.63e-05
# x5             4.8608      4.017      1.210      0.228      -3.087      12.808
# ==============================================================================
# Omnibus:                      264.599   Durbin-Watson:                   1.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56994.737
# Skew:                           9.463   Prob(JB):                         0.00
# Kurtosis:                     101.865   Cond. No.                     6.62e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.62e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #patriots
# Started building feature vector for #sb49
# Linear Regression Model for #sb49
#
# MSE : 376815.3045315723
# R-squared : 0.40977482771752705
# P values for the features are
#  [0.51368866 0.001652   0.28473384 0.56274336 0.96774985 0.49516809]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     17.91
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.85e-13
# Time:                        12:27:17   Log-Likelihood:                -1058.2
# No. Observations:                 135   AIC:                             2128.
# Df Residuals:                     129   BIC:                             2146.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.3516    107.421      0.655      0.514    -142.183     282.887
# x1             0.6604      0.205      3.214      0.002       0.254       1.067
# x2            -0.0276      0.026     -1.074      0.285      -0.078       0.023
# x3          6.682e-06   1.15e-05      0.580      0.563   -1.61e-05    2.95e-05
# x4         -1.025e-06   2.53e-05     -0.041      0.968   -5.11e-05     4.9e-05
# x5             5.4666      7.992      0.684      0.495     -10.345      21.278
# ==============================================================================
# Omnibus:                      243.292   Durbin-Watson:                   1.593
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37471.518
# Skew:                           8.126   Prob(JB):                         0.00
# Kurtosis:                      82.984   Cond. No.                     3.77e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.77e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #sb49
# Started building feature vector for #superbowl
#
# Linear Regression Model for #superbowl
#
# MSE : 267975.81586138636
# R-squared : 0.6723019443371393
# P values for the features are
#  [3.29671077e-01 3.65492858e-07 1.59681972e-02 3.44986919e-01
#  4.14163326e-01 9.46714085e-01]
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     52.93
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):           1.25e-29
# Time:                        12:29:14   Log-Likelihood:                -1035.2
# No. Observations:                 135   AIC:                             2082.
# Df Residuals:                     129   BIC:                             2100.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         96.0140     98.126      0.978      0.330     -98.131     290.159
# x1             0.8343      0.156      5.363      0.000       0.526       1.142
# x2            -0.0484      0.020     -2.442      0.016      -0.088      -0.009
# x3          7.253e-06   7.65e-06      0.948      0.345   -7.89e-06    2.24e-05
# x4          1.787e-05   2.18e-05      0.819      0.414   -2.53e-05     6.1e-05
# x5            -0.4404      6.577     -0.067      0.947     -13.453      12.572
# ==============================================================================
# Omnibus:                      208.825   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14376.981
# Skew:                           6.434   Prob(JB):                         0.00
# Kurtosis:                      51.891   Cond. No.                     4.52e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.52e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
# Finished #superbowl
