# %% [markdown]
# ### QUESTION 6:
#
# We define three time periods and their corresponding window length as follows:
# 1. Before Feb. 1, 8:00 a.m.: 1-hour window
# 2. Between Feb. 1, 8:00 a.m. and 8:00 p.m.: 5-minute window
# 3. After Feb. 1, 8:00 p.m.: 1-hour window
#
# For each hashtag, train 3 regression models, one for each of these time periods (the times are all in PST). Report the MSE and R-squared score for each case.

# %%
hash_tags = ['#gohawks','#gopatriots','#nfl','#patriots','#sb49','#superbowl']

# %%
import pickle

def save_object(data, fileName):
    with open('pynb_data/'+fileName + ".pickle", 'wb') as f:
        pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
        
def load_object(fileName):
    try:
        with open('pynb_data/'+fileName + ".pickle", 'rb') as f:
            data = pickle.load(f)
            return data
    except IOError:
        print("Could not read file: " + fileName)

# %%
import json

def getMinAndMaxTs(tag):
    filename = 'data/tweets_'+tag+'.txt'
    max_ts = 0
    min_ts = 1552522378
    with open(filename) as f:
        for line in f:
            json_object = json.loads(line)
            timestamp = json_object['citation_date']
            if(timestamp < min_ts):                
                min_ts = timestamp
            
            if(timestamp > max_ts):
                max_ts = timestamp
                
    return [min_ts,max_ts]

tagsToMinTs = {}
tagsToMaxTs = {}
for tag in hash_tags:
    ts_list = getMinAndMaxTs(tag)
    tagsToMinTs[tag] = (ts_list[0])
    tagsToMaxTs[tag] = (ts_list[1])

# %%
import math
import datetime
import pytz


def getLocalHour(timestamp):
    d = datetime.datetime.fromtimestamp(timestamp)
    pst = pytz.timezone('America/Los_Angeles')
    d = pst.localize(d)
    return d.hour

def getWindowNumber(start_ts, curr_ts, window):
    elapsed = (curr_ts - start_ts)/(window*1.0)
    windowNum = math.ceil(elapsed)
    return windowNum    

def getFeatures(tag,start_ts,end_ts,window):
    windowToTweets = {}
    windowToRetweets = {}
    windowToFollowerCount = {}
    windowToMaxFollowers = {}
    features = []
    labels = []
    
    filename = 'data/tweets_'+tag+'.txt'
    with open(filename) as f:
        for line in f:
            json_object = json.loads(line)
            timestamp = json_object['citation_date']
            
            if timestamp < start_ts or timestamp > end_ts:                            
                continue
                
            key = getWindowNumber(start_ts,timestamp,window)
#             print(key)
            if key not in windowToTweets.keys():
                windowToTweets[key]=0
            windowToTweets[key]+=1
            
            retweetCount = json_object['metrics']['citations']['total']        
            
            if key not in windowToRetweets.keys():
                windowToRetweets[key]=0
            windowToRetweets[key]+=retweetCount
        
            followerCount = json_object['author']['followers']
            if key not in windowToFollowerCount.keys():
                windowToFollowerCount[key]=0
            windowToFollowerCount[key]+=followerCount
        
            if key not in windowToMaxFollowers.keys():
                windowToMaxFollowers[key]=0
            windowToMaxFollowers[key] = max(windowToMaxFollowers[key],followerCount)            
            
        for period in range(start_ts,end_ts,window):
            key = getWindowNumber(start_ts,period,window)
            tweetCount = windowToTweets.get(key, 0)
            retweetCount = windowToRetweets.get(key,0)
            followerCount = windowToFollowerCount.get(key,0)
            maxFollowers = windowToMaxFollowers.get(key,0)

            h = getLocalHour(key)
            
            feature = [tweetCount, retweetCount, followerCount, maxFollowers, h]
            features.append(feature)
                
            nextKey = getWindowNumber(start_ts, period + window, window)
            labels.append(windowToTweets.get(nextKey,0))
                
    return features,labels

# %%
print("Building feature vectors for time period 1")

for tag in hash_tags:
    print("Started building feature vector for {}".format(tag))
    tp1_window_size = 3600 # 1 hour window size
    tp1_start_ts = tp1_window_size * math.floor(tagsToMinTs[tag]/(tp1_window_size*1.0))
    tp1_end_ts = 1422806400
    features,labels = getFeatures(tag,tp1_start_ts,tp1_end_ts,tp1_window_size)
    print(labels)
    print("No. of features: "+str(len(features)))
    save_object(features, "tp1_features_{}".format(tag))
    save_object(labels, "tp1_labels_{}".format(tag))
    print("Finished building feature vector for {}".format(tag))
# Out:
# Building feature vectors for time period 1
# Started building feature vector for #gohawks
# [29, 13, 14, 9, 24, 29, 43, 71, 127, 140, 123, 115, 125, 162, 131, 123, 85, 77, 67, 122, 126, 94, 80, 37, 10, 19, 12, 13, 17, 23, 40, 89, 155, 133, 75, 151, 164, 147, 151, 133, 101, 150, 129, 158, 91, 82, 82, 20, 56, 9, 4, 4, 22, 31, 71, 278, 436, 453, 327, 419, 450, 346, 380, 348, 241, 377, 385, 235, 220, 182, 151, 98, 53, 36, 16, 19, 18, 15, 39, 111, 182, 244, 164, 359, 354, 311, 278, 264, 173, 300, 254, 353, 272, 276, 309, 247, 275, 124, 67, 3, 75, 133, 334, 792, 1094, 1467, 1316, 3653, 6678, 3893, 4392, 18606, 3673, 1598, 1488, 1309, 964, 696, 570, 350, 226, 139, 75, 86, 93, 94, 180, 282, 362, 440, 245, 375, 362, 333, 251, 256, 132, 196, 204, 218, 195, 226, 133, 120, 79, 33, 26, 23, 27, 26, 67, 110, 150, 177, 103, 158, 5, 19, 144, 162, 103, 216, 282, 228, 258, 201, 157, 89, 44, 19, 22, 24, 24, 27, 49, 71, 67, 88, 82, 87, 112, 83, 85, 122, 161, 182, 185, 192, 150, 124, 77, 70, 31, 15, 14, 12, 12, 16, 48, 76, 138, 150, 85, 66, 67, 8, 10, 13, 77, 153, 151, 172, 185, 178, 132, 71, 40, 19, 17, 16, 23, 29, 101, 147, 180, 125, 194, 183, 192, 186, 193, 154, 300, 240, 303, 176, 142, 119, 87, 61, 32, 29, 49, 14, 6, 34, 48, 75, 119, 125, 178, 171, 286, 155, 159, 106, 126, 134, 138, 143, 136, 146, 94, 58, 27, 30, 13, 19, 18, 22, 36, 108, 260, 419, 648, 363, 275, 299, 250, 233, 184, 270, 246, 205, 161, 158, 114, 64, 38, 6, 79, 19, 20, 33, 57, 116, 186, 161, 179, 197, 148, 148, 219, 134, 147, 171, 196, 272, 344, 203, 188, 98, 38, 29, 26, 19, 41, 83, 90, 152, 195, 324, 354, 796, 534, 296, 290, 260, 202, 245, 217, 226, 272, 220, 157, 101, 41, 38, 15, 29, 34, 32, 73, 142, 211, 268, 293, 257, 236, 235, 256, 213, 228, 260, 224, 320, 79, 11, 9, 7, 16, 12,
 179, 155, 115, 307, 230, 150, 91, 61, 43, 48, 63, 135, 103, 113, 158, 167, 171, 246, 210, 194, 199, 153, 254, 219, 234, 204, 192, 139, 105, 83, 66, 36, 31, 33, 37, 61, 74, 163, 190, 329, 336, 207, 148, 123, 28, 25, 26, 136, 389, 209, 223, 203, 152, 114, 62, 67, 61, 51, 86, 84, 118, 233, 362, 320, 227, 305, 290, 327, 262, 268, 161, 231, 206, 147, 132, 140, 98, 63, 60, 50, 32, 31, 39, 42, 94, 113, 148, 183, 165, 313, 195, 508, 251, 256, 186, 149, 146, 167, 143, 132, 105, 82, 55, 57, 32, 33, 43, 65, 74, 119, 161, 327, 274, 320, 320, 316, 290, 294, 251, 226, 278, 307, 217, 264, 154, 90, 84, 67, 50, 48, 105, 127, 177, 270, 377, 494, 401, 378, 486, 249, 324, 495, 369, 363, 2552, 606, 383, 423, 231, 142, 106, 75, 75, 87, 115, 155, 262, 312, 443, 542, 797, 766, 1034, 752, 652, 631, 601, 445, 440, 489, 380, 505, 310, 201, 157, 124, 100, 112, 186, 255, 196, 266, 581, 712, 851, 793, 783, 744, 685, 791, 721, 620, 577, 459, 377, 112, 21, 13, 17, 227, 259, 347, 380, 447, 665, 913, 1217, 1390, 1655, 1509, 1087, 889, 1022, 1048, 982, 1259, 1124, 687, 962, 345, 193, 508, 386, 378, 320, 373, 689, 578, 254, 586, 2062, 2596, 1816, 2434, 3381, 3157, 2592, 2399, 1337, 723, 202, 415, 241, 237, 239, 184, 135, 129, 144, 145, 146, 229, 311, 438, 582, 682, 749, 787, 637, 909, 782, 879, 793, 2071, 2335, 1984, 922, 1708, 1492, 1446, 1031, 916, 1216, 1292, 1497, 2007, 3502, 5357, 7160]
# No. of features: 440
# Finished building feature vector for #superbowl

# %%
import statsmodels.api as sm

for tag in hash_tags:
    print('\nLinear Regression Model for {}'.format(tag))
    X_orig = load_object("tp1_features_{}".format(tag))
    y = load_object("tp1_labels_{}".format(tag))
    
    #     https://becominghuman.ai/stats-models-vs-sklearn-for-linear-regression-f19df95ad99b
    X = sm.add_constant(X_orig)
    
    model = sm.OLS(y,X)
    results = model.fit()
    #     print(results.pvalues)
    print(results.summary())
    print('---'*20)
    print('\n\n')
# Out:
# Linear Regression Model for #gohawks
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.303
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     47.32
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           5.01e-33
# Time:                        20:51:22   Log-Likelihood:                -3590.5
# No. Observations:                 440   AIC:                             7191.
# Df Residuals:                     435   BIC:                             7211.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             2.0478      0.283      7.242      0.000       1.492       2.604
# x2            -0.3955      0.112     -3.539      0.000      -0.615      -0.176
# x3            -0.0005      0.000     -3.077      0.002      -0.001      -0.000
# x4             0.0004      0.000      2.032      0.043    1.35e-05       0.001
# const          8.6584      2.748      3.151      0.002       3.257      14.059
# ==============================================================================
# Omnibus:                      869.102   Durbin-Watson:                   2.209
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1054638.131
# Skew:                          13.282   Prob(JB):                         0.00
# Kurtosis:                     241.370   Cond. No.                     1.47e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #gopatriots
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.572
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     145.2
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           1.12e-78
# Time:                        20:51:22   Log-Likelihood:                -2262.1
# No. Observations:                 439   AIC:                             4534.
# Df Residuals:                     434   BIC:                             4555.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.7928      0.184      9.748      0.000       1.431       2.154
# x2            -0.0916      0.115     -0.798      0.425      -0.317       0.134
# x3            -0.0010      0.000     -6.078      0.000      -0.001      -0.001
# x4             0.0010      0.000      6.148      0.000       0.001       0.001
# const          0.0721      0.135      0.534      0.594      -0.193       0.338
# ==============================================================================
# Omnibus:                      748.444   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           411316.793
# Skew:                           9.926   Prob(JB):                         0.00
# Kurtosis:                     151.635   Cond. No.                     2.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #nfl
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     114.0
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           2.20e-66
# Time:                        20:51:22   Log-Likelihood:                -3065.2
# No. Observations:                 440   AIC:                             6140.
# Df Residuals:                     435   BIC:                             6161.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4728      0.101      4.700      0.000       0.275       0.670
# x2             0.0019      0.046      0.041      0.968      -0.089       0.093
# x3          6.794e-05   1.84e-05      3.700      0.000    3.19e-05       0.000
# x4         -6.083e-05   2.31e-05     -2.635      0.009      -0.000   -1.54e-05
# const          5.3725      0.986      5.450      0.000       3.435       7.310
# ==============================================================================
# Omnibus:                      735.310   Durbin-Watson:                   2.263
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           464762.915
# Skew:                           9.431   Prob(JB):                         0.00
# Kurtosis:                     161.098   Cond. No.                     2.30e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #patriots
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     142.5
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           9.85e-78
# Time:                        20:51:22   Log-Likelihood:                -3424.8
# No. Observations:                 440   AIC:                             6860.
# Df Residuals:                     435   BIC:                             6880.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.2998      0.184     -1.625      0.105      -0.662       0.063
# x2             0.1402      0.076      1.849      0.065      -0.009       0.289
# x3             0.0002   3.02e-05      7.459      0.000       0.000       0.000
# x4            -0.0003   4.81e-05     -6.367      0.000      -0.000      -0.000
# const          4.6154      1.990      2.319      0.021       0.703       8.527
# ==============================================================================
# Omnibus:                      564.742   Durbin-Watson:                   2.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190433.446
# Skew:                           5.684   Prob(JB):                         0.00
# Kurtosis:                     104.282   Cond. No.                     2.97e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #sb49
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     691.7
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):          5.16e-186
# Time:                        20:51:22   Log-Likelihood:                -2549.3
# No. Observations:                 436   AIC:                             5109.
# Df Residuals:                     431   BIC:                             5129.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.0583      0.041     26.092      0.000       0.979       1.138
# x2             0.0227      0.005      4.632      0.000       0.013       0.032
# x3         -4.291e-06   1.38e-06     -3.103      0.002   -7.01e-06   -1.57e-06
# x4          2.966e-06   3.43e-06      0.866      0.387   -3.77e-06     9.7e-06
# const          0.0127      0.282      0.045      0.964      -0.541       0.567
# ==============================================================================
# Omnibus:                      236.390   Durbin-Watson:                   1.427
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8447.471
# Skew:                           1.667   Prob(JB):                         0.00
# Kurtosis:                      24.304   Cond. No.                     6.65e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #superbowl
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     73.10
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           2.40e-47
# Time:                        20:51:22   Log-Likelihood:                -3517.9
# No. Observations:                 440   AIC:                             7046.
# Df Residuals:                     435   BIC:                             7066.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3768      0.123      3.066      0.002       0.135       0.618
# x2             0.0439      0.060      0.734      0.463      -0.074       0.161
# x3          2.653e-05   5.88e-06      4.513      0.000     1.5e-05    3.81e-05
# x4         -3.878e-05   2.47e-05     -1.569      0.117   -8.74e-05     9.8e-06
# const          7.8594      2.624      2.995      0.003       2.701      13.017
# ==============================================================================
# Omnibus:                      626.630   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           112614.420
# Skew:                           7.333   Prob(JB):                         0.00
# Kurtosis:                      79.990   Cond. No.                     1.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------

# %%
print("Building feature vectors for time period 2")

#tp2
for tag in hash_tags:
    print("Started building feature vector for {}".format(tag))
    tp2_window_size = 300 # 5 minute window size
    tp2_start_ts = 1422806400
    tp2_end_ts = 1422849600
    features,labels = getFeatures(tag,tp2_start_ts,tp2_end_ts,tp2_window_size)
    print(labels)
    print("No. of features: "+str(len(features)))
    save_object(features, "tp2_features_{}".format(tag))
    save_object(labels, "tp2_labels_{}".format(tag))
    print("Finished {}".format(tag))
# Out:
# Building feature vectors for time period 2
# Started building feature vector for #gohawks
# [27, 46, 35, 36, 32, 9, 1, 13, 5, 3, 9, 15, 16, 6, 11, 15, 45, 38, 59, 37, 36, 43, 35, 54, 232, 212, 201, 203, 220, 255, 236, 219, 228, 235, 258, 225, 164, 231, 234, 251, 234, 250, 249, 250, 228, 273, 213, 255, 263, 290, 279, 301, 271, 289, 282, 262, 255, 312, 290, 295, 301, 296, 287, 287, 314, 352, 311, 287, 220, 279, 273, 297, 342, 298, 315, 320, 312, 325, 427, 483, 448, 432, 491, 598, 827, 791, 1121, 826, 1071, 1330, 1329, 680, 474, 482, 1438, 893, 427, 406, 488, 406, 373, 346, 1757, 1020, 426, 337, 324, 1738, 1608, 731, 393, 230, 231, 383, 452, 818, 465, 825, 1848, 1316, 548, 511, 665, 413, 487, 457, 407, 349, 292, 739, 918, 1615, 247, 501, 478, 384, 340, 303, 236, 251, 214, 206, 104, 16]
# No. of features: 144
# Finished #gohawks
# Started building feature vector for #gopatriots
# [4, 7, 6, 5, 4, 0, 1, 1, 2, 0, 0, 1, 1, 0, 2, 3, 4, 1, 6, 4, 2, 7, 0, 9, 28, 23, 25, 26, 29, 24, 29, 20, 26, 28, 36, 31, 15, 21, 26, 37, 31, 39, 32, 38, 27, 38, 36, 31, 39, 35, 47, 48, 38, 42, 43, 58, 56, 42, 49, 42, 37, 60, 56, 50, 47, 54, 64, 49, 45, 48, 48, 63, 68, 74, 75, 75, 70, 70, 112, 91, 104, 131, 110, 161, 240, 223, 265, 209, 295, 390, 448, 252, 203, 193, 204, 161, 133, 154, 846, 303, 217, 141, 147, 143, 120, 686, 339, 171, 183, 172, 107, 63, 79, 115, 181, 141, 99, 97, 131, 132, 62, 70, 73, 86, 68, 370, 208, 178, 160, 852, 447, 164, 797, 768, 436, 272, 161, 133, 106, 95, 75, 68, 37, 3]
# No. of features: 144
# Finished #sb49
# Started building feature vector for #superbowl
# [812, 841, 702, 758, 745, 208, 173, 131, 161, 157, 185, 158, 267, 180, 201, 251, 896, 948, 1010, 912, 945, 788, 686, 1042, 848, 699, 687, 693, 822, 776, 790, 686, 757, 750, 728, 775, 510, 693, 869, 835, 827, 910, 856, 834, 870, 819, 798, 899, 1047, 980, 955, 861, 939, 972, 1058, 945, 966, 975, 984, 1047, 1209, 1100, 1050, 1006, 1058, 1146, 1200, 1060, 929, 1035, 1072, 1049, 1440, 1453, 1443, 1535, 1577, 1460, 1867, 2232, 2225, 2334, 2534, 3280, 9445, 8862, 14321, 14044, 20674, 17895, 19964, 12808, 12331, 11520, 14632, 14148, 13785, 14594, 18745, 14992, 13967, 17086, 17847, 17355, 14485, 14562, 13658, 15888, 22366, 16971, 25857, 35269, 35014, 27908, 16957, 16082, 13282, 11138, 14737, 13899, 8905, 9162, 7853, 7808, 8988, 10158, 10528, 8002, 6900, 13086, 11098, 15894, 26215, 27816, 15755, 10817, 8831, 7956, 5848, 5009, 4224, 3672, 2011, 416]
# No. of features: 144
# Finished #superbowl

# %%
for tag in hash_tags:
    print('\nLinear Regression Model for {}'.format(tag))
    X_orig = load_object("tp2_features_{}".format(tag))
    y = load_object("tp2_labels_{}".format(tag))
    
    #     https://becominghuman.ai/stats-models-vs-sklearn-for-linear-regression-f19df95ad99b
    X = sm.add_constant(X_orig)
    
    model = sm.OLS(y,X)
    results = model.fit()
    #     print(results.pvalues)
    print(results.summary())
    print('---'*20)
    print('\n\n')
# Out:
# Linear Regression Model for #gohawks
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     31.26
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           1.45e-18
# Time:                        20:56:41   Log-Likelihood:                -1012.4
# No. Observations:                 144   AIC:                             2035.
# Df Residuals:                     139   BIC:                             2050.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7838      0.213      3.679      0.000       0.363       1.205
# x2             0.0878      0.168      0.521      0.603      -0.245       0.421
# x3            -0.0002   7.88e-05     -2.196      0.030      -0.000   -1.73e-05
# x4             0.0003      0.000      1.956      0.052   -2.92e-06       0.001
# const          6.3128      2.301      2.744      0.007       1.764      10.862
# ==============================================================================
# Omnibus:                      102.090   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              940.714
# Skew:                           2.417   Prob(JB):                    5.33e-205
# Kurtosis:                      14.550   Cond. No.                     1.47e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #gopatriots
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     25.77
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           5.48e-16
# Time:                        20:56:41   Log-Likelihood:                -895.35
# No. Observations:                 144   AIC:                             1801.
# Df Residuals:                     139   BIC:                             1816.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0387      0.357     -0.108      0.914      -0.745       0.668
# x2             0.7287      0.279      2.613      0.010       0.177       1.280
# x3            -0.0002      0.000     -1.316      0.191      -0.001       0.000
# x4             0.0002      0.000      0.974      0.332      -0.000       0.001
# const          2.2639      0.841      2.693      0.008       0.602       3.926
# ==============================================================================
# Omnibus:                      151.926   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2525.737
# Skew:                           3.996   Prob(JB):                         0.00
# Kurtosis:                      21.897   Cond. No.                     2.47e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #nfl
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     150.6
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           1.72e-49
# Time:                        20:56:41   Log-Likelihood:                -922.78
# No. Observations:                 144   AIC:                             1856.
# Df Residuals:                     139   BIC:                             1870.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.2571      0.107     11.761      0.000       1.046       1.468
# x2            -0.1259      0.049     -2.578      0.011      -0.222      -0.029
# x3         -4.344e-05   2.64e-05     -1.646      0.102   -9.56e-05    8.75e-06
# x4          1.533e-05   3.66e-05      0.419      0.676   -5.69e-05    8.76e-05
# const          2.2656      1.106      2.049      0.042       0.079       4.452
# ==============================================================================
# Omnibus:                       66.710   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              355.920
# Skew:                           1.562   Prob(JB):                     5.16e-78
# Kurtosis:                      10.040   Cond. No.                     2.20e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #patriots
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     81.23
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           2.08e-35
# Time:                        20:56:41   Log-Likelihood:                -1173.1
# No. Observations:                 144   AIC:                             2356.
# Df Residuals:                     139   BIC:                             2371.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.9695      0.249      3.894      0.000       0.477       1.462
# x2            -0.0276      0.224     -0.123      0.902      -0.471       0.416
# x3          -8.79e-05   4.75e-05     -1.852      0.066      -0.000    5.96e-06
# x4             0.0001      0.000      1.000      0.319      -0.000       0.000
# const         22.9221      7.336      3.125      0.002       8.418      37.426
# ==============================================================================
# Omnibus:                      123.265   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1198.903
# Skew:                           3.153   Prob(JB):                    4.59e-261
# Kurtosis:                      15.651   Cond. No.                     5.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #sb49
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     221.5
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           3.03e-59
# Time:                        20:56:41   Log-Likelihood:                -1218.6
# No. Observations:                 144   AIC:                             2447.
# Df Residuals:                     139   BIC:                             2462.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.9743      0.056     17.411      0.000       0.864       1.085
# x2            -0.0231      0.039     -0.592      0.555      -0.100       0.054
# x3         -1.901e-06   6.88e-06     -0.276      0.783   -1.55e-05    1.17e-05
# x4          1.531e-05   1.72e-05      0.888      0.376   -1.88e-05    4.94e-05
# const         18.9036     11.230      1.683      0.095      -3.299      41.107
# ==============================================================================
# Omnibus:                       41.285   Durbin-Watson:                   2.306
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              621.036
# Skew:                          -0.364   Prob(JB):                    1.39e-135
# Kurtosis:                      13.148   Cond. No.                     5.64e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #superbowl
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.887
# Method:                 Least Squares   F-statistic:                     280.4
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           1.77e-65
# Time:                        20:56:41   Log-Likelihood:                -1337.7
# No. Observations:                 144   AIC:                             2685.
# Df Residuals:                     139   BIC:                             2700.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.0667      0.088     12.121      0.000       0.893       1.241
# x2            -0.0359      0.016     -2.279      0.024      -0.067      -0.005
# x3          -1.09e-05   1.55e-05     -0.705      0.482   -4.15e-05    1.97e-05
# x4          8.493e-05    6.2e-05      1.370      0.173   -3.77e-05       0.000
# const          8.9497     19.879      0.450      0.653     -30.355      48.254
# ==============================================================================
# Omnibus:                       43.655   Durbin-Watson:                   1.498
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.536
# Skew:                           0.855   Prob(JB):                     4.88e-59
# Kurtosis:                       9.468   Cond. No.                     6.13e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.13e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------

# %%
print("Building feature vectors for time period 3")

#tp3
for tag in hash_tags:
    print("Started building feature vector for {}".format(tag))
    tp3_window_size = 3600 # 1 hour window size
    tp3_start_ts = 1422849600
    tp3_end_ts = tp3_window_size * math.ceil(tagsToMaxTs[tag]/(tp3_window_size*1.0))
    features,labels = getFeatures(tag,tp3_start_ts,tp3_end_ts,tp3_window_size)
    save_object(features, "tp3_features_{}".format(tag))
    save_object(labels, "tp3_labels_{}".format(tag))
    print("Finished {}".format(tag))
# Out:
# Building feature vectors for time period 3
# Started building feature vector for #gohawks
# Finished #gohawks
# Started building feature vector for #gopatriots
# Finished #gopatriots
# Started building feature vector for #nfl
# Finished #nfl
# Started building feature vector for #patriots
# Finished #patriots
# Started building feature vector for #sb49
# Finished #sb49
# Started building feature vector for #superbowl
# Finished #superbowl

# %%
for tag in hash_tags:
    print('\nLinear Regression Model for {}'.format(tag))
    X_orig = load_object("tp3_features_{}".format(tag))
    y = load_object("tp3_labels_{}".format(tag))
    
    #     https://becominghuman.ai/stats-models-vs-sklearn-for-linear-regression-f19df95ad99b
    X = sm.add_constant(X_orig)
    
    model = sm.OLS(y,X)
    results = model.fit()
    #     print(results.pvalues)
    print(results.summary())
    print('---'*20)
    print('\n\n')
# Out:
# Linear Regression Model for #gohawks
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     29.23
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           4.82e-17
# Time:                        21:00:31   Log-Likelihood:                -758.84
# No. Observations:                 127   AIC:                             1528.
# Df Residuals:                     122   BIC:                             1542.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0972      0.245      0.397      0.692      -0.387       0.582
# x2            -0.0269      0.021     -1.309      0.193      -0.067       0.014
# x3             0.0009      0.000      2.490      0.014       0.000       0.002
# x4            -0.0009      0.000     -2.411      0.017      -0.002      -0.000
# const          0.9950      0.584      1.705      0.091      -0.161       2.150
# ==============================================================================
# Omnibus:                      229.801   Durbin-Watson:                   1.245
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            32012.064
# Skew:                           7.996   Prob(JB):                         0.00
# Kurtosis:                      79.117   Cond. No.                     2.09e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #gopatriots
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     9.691
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           8.08e-07
# Time:                        21:00:31   Log-Likelihood:                -540.75
# No. Observations:                 124   AIC:                             1091.
# Df Residuals:                     119   BIC:                             1106.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5571      0.521      1.069      0.287      -0.474       1.589
# x2             0.0238      0.053      0.449      0.655      -0.081       0.129
# x3            -0.0004      0.001     -0.338      0.736      -0.002       0.002
# x4             0.0006      0.001      0.491      0.624      -0.002       0.003
# const          0.1958      0.116      1.691      0.094      -0.034       0.425
# ==============================================================================
# Omnibus:                      240.611   Durbin-Watson:                   1.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            42845.281
# Skew:                           8.960   Prob(JB):                         0.00
# Kurtosis:                      92.283   Cond. No.                     5.47e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #nfl
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     113.5
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           2.03e-41
# Time:                        21:00:31   Log-Likelihood:                -856.41
# No. Observations:                 135   AIC:                             1723.
# Df Residuals:                     130   BIC:                             1737.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8207      0.116      7.050      0.000       0.590       1.051
# x2            -0.0314      0.047     -0.667      0.506      -0.125       0.062
# x3          3.032e-05   2.71e-05      1.119      0.265   -2.33e-05    8.39e-05
# x4         -3.512e-05   3.84e-05     -0.915      0.362      -0.000    4.09e-05
# const          4.2182      1.577      2.675      0.008       1.098       7.338
# ==============================================================================
# Omnibus:                       46.605   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              134.719
# Skew:                           1.311   Prob(JB):                     5.57e-30
# Kurtosis:                       7.132   Cond. No.                     3.84e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.84e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #patriots
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     22.88
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           2.49e-14
# Time:                        21:00:31   Log-Likelihood:                -969.24
# No. Observations:                 135   AIC:                             1948.
# Df Residuals:                     130   BIC:                             1963.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6026      0.275      2.194      0.030       0.059       1.146
# x2            -0.0427      0.017     -2.583      0.011      -0.075      -0.010
# x3          6.802e-05   3.81e-05      1.784      0.077    -7.4e-06       0.000
# x4         -6.961e-05   4.68e-05     -1.488      0.139      -0.000    2.29e-05
# const          3.4716      2.152      1.613      0.109      -0.786       7.729
# ==============================================================================
# Omnibus:                      267.782   Durbin-Watson:                   1.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            60453.012
# Skew:                           9.678   Prob(JB):                         0.00
# Kurtosis:                     104.846   Cond. No.                     2.55e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #sb49
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     22.36
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           4.55e-14
# Time:                        21:00:31   Log-Likelihood:                -1058.5
# No. Observations:                 135   AIC:                             2127.
# Df Residuals:                     130   BIC:                             2141.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6590      0.205      3.214      0.002       0.253       1.065
# x2            -0.0249      0.025     -0.984      0.327      -0.075       0.025
# x3          5.809e-06   1.14e-05      0.509      0.612   -1.68e-05    2.84e-05
# x4          2.281e-06   2.48e-05      0.092      0.927   -4.67e-05    5.13e-05
# const          7.7843      4.524      1.721      0.088      -1.167      16.735
# ==============================================================================
# Omnibus:                      246.224   Durbin-Watson:                   1.594
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39632.554
# Skew:                           8.303   Prob(JB):                         0.00
# Kurtosis:                      85.280   Cond. No.                     1.59e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
#
#
#
#
# Linear Regression Model for #superbowl
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     66.67
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):           1.44e-30
# Time:                        21:00:31   Log-Likelihood:                -1035.2
# No. Observations:                 135   AIC:                             2080.
# Df Residuals:                     130   BIC:                             2095.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8340      0.155      5.384      0.000       0.528       1.141
# x2            -0.0484      0.020     -2.452      0.016      -0.087      -0.009
# x3          7.241e-06   7.62e-06      0.950      0.344   -7.84e-06    2.23e-05
# x4          1.779e-05   2.17e-05      0.820      0.414   -2.51e-05    6.07e-05
# const          5.7238      4.510      1.269      0.207      -3.199      14.647
# ==============================================================================
# Omnibus:                      208.535   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14286.076
# Skew:                           6.420   Prob(JB):                         0.00
# Kurtosis:                      51.733   Cond. No.                     2.08e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ------------------------------------------------------------
